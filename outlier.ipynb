# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 437  6.73                  22.0       0
# 105  6.72                  12.0       1
# 841  7.45                  27.0       1
# 404  8.02                  35.0       1
# 446  6.60                  23.0       1

# %%
plt.figure(figsize=(16, 5))

plt.subplot(1, 2, 1)
sns.kdeplot(df['cgpa'].dropna())
plt.title("CGPA KDE")

plt.subplot(1, 2, 2)
sns.kdeplot(df['placement_exam_marks'].dropna())
plt.title("Placement Exam Marks KDE")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 plt.figure(figsize=(16, 5))
#       3 plt.subplot(1, 2, 1)
# ----> 4 sns.kdeplot(df['cgpa'].dropna())
#       5 plt.title("CGPA KDE")
#       7 plt.subplot(1, 2, 2)
#
# NameError: name 'df' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df['placement_exam_marks'].skew()
#
# NameError: name 'df' is not defined
